# %% [markdown]
# # Extreme Event Risk Analytics
#
# ## Objective
# This notebook outlines the motivation and high-level plan for analyzing rare, high-impact events and their effect on risk metrics.
#
# The focus of this project is understanding tail risk rather than average outcomes.
